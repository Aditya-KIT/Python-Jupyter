# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('Marks.csv')
df
# Out:
#      number_courses  time_study   Marks
# 0                 3       4.508  19.202
# 1                 4       0.096   7.734
# 2                 4       3.133  13.811
# 3                 6       7.909  53.018
# 4                 8       7.811  55.299
# ..              ...         ...     ...
# 96                3       0.301   5.609
# 97                4       7.163  41.444
# 98                7       0.309  12.027
# 99                3       6.335  32.357
# 100               4       3.210     NaN
#
# [101 rows x 3 columns]

# %% [markdown]
# # Info() is a function of Pandas

# %%
# Info function is used to tell Number of entries means Rows & Columns | Columns Data types & how many non null columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  101 non-null    int64
#  1   time_study      101 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %% [markdown]
# # isnull()

# %%
# isnull() is used to find Null values in the table

# %%
df.isnull()
# Out:
#      number_courses  time_study  Marks
# 0             False       False  False
# 1             False       False  False
# 2             False       False  False
# 3             False       False  False
# 4             False       False  False
# ..              ...         ...    ...
# 96            False       False  False
# 97            False       False  False
# 98            False       False  False
# 99            False       False  False
# 100           False       False   True
#
# [101 rows x 3 columns]

# %%
# isnull().sum() is used to find numbers of NAN value present in table

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             1
# dtype: int64

# %%
# fillna is used to convert NAN value to numeric value | .replace is used to replace value

# %%
df["Marks"] = df["Marks"].fillna(3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  101 non-null    int64
#  1   time_study      101 non-null    float64
#  2   Marks           101 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.isnull()
# Out:
#      number_courses  time_study  Marks
# 0             False       False  False
# 1             False       False  False
# 2             False       False  False
# 3             False       False  False
# 4             False       False  False
# ..              ...         ...    ...
# 96            False       False  False
# 97            False       False  False
# 98            False       False  False
# 99            False       False  False
# 100           False       False  False
#
# [101 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # describe()

# %%
# describe() is used to view table in breif

# %%
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      101.000000  101.000000  101.000000
# mean         5.277228    4.068554   24.205634
# std          1.795098    2.362596   14.412818
# min          3.000000    0.096000    3.000000
# 25%          4.000000    2.061000   12.591000
# 50%          5.000000    3.977000   19.771000
# 75%          7.000000    6.173000   36.653000
# max          8.000000    7.957000   55.299000

# %%
df.head(20)   # first 20 rows
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# 5                6       3.211  17.822
# 6                3       6.063  29.889
# 7                5       3.413  17.264
# 8                4       4.410  20.348
# 9                3       6.173  30.862
# 10               3       7.353  42.036
# 11               7       0.423  12.132
# 12               7       4.218  24.318
# 13               3       4.274  17.672
# 14               3       2.908  11.397
# 15               4       4.260  19.466
# 16               5       5.719  30.548
# 17               8       6.080  38.490
# 18               6       7.711  50.986
# 19               8       3.977  25.133

# %%
df.tail(20)   # last 20 rows
# Out:
#      number_courses  time_study   Marks
# 81                8       2.262  17.705
# 82                4       7.410  44.099
# 83                5       3.197  16.106
# 84                8       1.982  16.461
# 85                8       6.201  39.957
# 86                7       4.067  23.149
# 87                3       1.033   6.053
# 88                5       1.803  11.253
# 89                7       6.376  40.024
# 90                7       4.182  24.394
# 91                8       2.730  19.564
# 92                4       5.027  23.916
# 93                8       6.471  42.426
# 94                8       3.919  24.451
# 95                6       3.561  19.128
# 96                3       0.301   5.609
# 97                4       7.163  41.444
# 98                7       0.309  12.027
# 99                3       6.335  32.357
# 100               4       3.210   3.000

# %%
# The below function is used to show whole table for temporary purpose

# %%
""" with pd.option_context(
    'display.max_rows', None,
    'display.max_columns', None
):
    print(df) """
# Out:
# " with pd.option_context(\n    'display.max_rows', None,\n    'display.max_columns', None\n):\n    print(df) "

# %%
plt.title("Marks Histogram", fontsize=20)
sns.histplot(df['Marks'])
# Out:
# <Axes: title={'center': 'Marks Histogram'}, xlabel='Marks', ylabel='Count'>

# %% [markdown]
# # countplot()

# %%
# Countplot is a function of seaborn used to count No. of times value appears

# %%
val=sns.countplot(x='number_courses',data=df)

for container in val.containers:
    val.bar_label(container)
plt.show()

# %% [markdown]
# # Pie Distribrution

# %%
plt.figure(figsize=(4,5)) # Size of Pie chart
course_counts = df['number_courses'].value_counts()

plt.pie(
    course_counts,
    labels=course_counts.index,
    autopct='%1.2f%%'
)
plt.title("Percentage of Number of Courses", fontsize=12)
plt.show()
course_counts
# Out:
# number_courses
# 3    22
# 4    22
# 6    16
# 8    16
# 7    15
# 5    10
# Name: count, dtype: int64
